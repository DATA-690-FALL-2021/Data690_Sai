# %% [markdown]
# <a href="https://colab.research.google.com/github/px70339sai/Data690_Sai/blob/main/individual_project/Part_B_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("Pandas Version is ", pd.__version__)

import plotly 

print("Plotly Version is", plotly.__version__)

import plotly.graph_objects as go
import plotly.express as px
# Out:
# Pandas Version is  1.1.5
# Plotly Version is 4.4.1

# %%
df = pd.read_csv("https://raw.githubusercontent.com/DATA-690-FALL-2021/Data690_Sai/main/wdi_data%20(6).csv")
df.head()
# Out:
#    Unnamed: 0  Year  ...         Income Group    Lending Type
# 0           0  2018  ...  Upper middle income            IBRD
# 1           1  2015  ...          High income  Not classified
# 2           2  2016  ...          High income  Not classified
# 3           3  2017  ...          High income  Not classified
# 4           4  2018  ...          High income  Not classified
#
# [5 rows x 9 columns]

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)
df.head()
# Out:
#    Year  value  ...         Income Group    Lending Type
# 0  2018   25.0  ...  Upper middle income            IBRD
# 1  2015   19.1  ...          High income  Not classified
# 2  2016   18.9  ...          High income  Not classified
# 3  2017   19.3  ...          High income  Not classified
# 4  2018   18.7  ...          High income  Not classified
#
# [5 rows x 8 columns]

# %%
df.sample(10)
# Out:
#      Year      value  ...         Income Group    Lending Type
# 574  2007   1.226932  ...  Upper middle income            IBRD
# 349  2017  40.000000  ...  Upper middle income            IBRD
# 719  2016  20.700000  ...          High income  Not classified
# 253  2017  33.900000  ...          High income  Not classified
# 829  2019  30.100000  ...          High income  Not classified
# 273  2017  27.800000  ...          High income  Not classified
# 648  2012   0.768917  ...  Upper middle income            IBRD
# 386  2014   7.816234  ...  Upper middle income            IBRD
# 438  2005  22.113804  ...  Lower middle income            IBRD
# 225  2019  17.200000  ...  Upper middle income            IBRD
#
# [10 rows x 8 columns]

# %%
df_2000 = df.query("Year == 2020")

df_2000.sample(10)
# Out:
#      Year  value  ...         Income Group    Lending Type
# 64   2020   15.8  ...          High income  Not classified
# 661  2020   53.8  ...           Low income             IDA
# 749  2020   18.0  ...          High income  Not classified
# 708  2020   12.7  ...          High income  Not classified
# 85   2020   17.8  ...          High income  Not classified
# 814  2020   36.1  ...  Upper middle income            IBRD
# 192  2020   29.8  ...  Upper middle income            IBRD
# 149  2020   31.9  ...  Upper middle income            IBRD
# 240  2020   16.2  ...          High income  Not classified
# 44   2020   16.2  ...          High income  Not classified
#
# [10 rows x 8 columns]

# %%
poverty_headcount = pd.read_csv("/content/wdi_data (7).csv")
poverty_headcount.drop(columns=["Unnamed: 0"], inplace=True)
poverty_headcount.head()
# Out:
#    Year      value  ...         Income Group Lending Type
# 0  2004  16.963144  ...  Upper middle income         IBRD
# 1  2005  13.317249  ...  Upper middle income         IBRD
# 2  2006  10.317365  ...  Upper middle income         IBRD
# 3  2007   8.750589  ...  Upper middle income         IBRD
# 4  2008   8.210397  ...  Upper middle income         IBRD
#
# [5 rows x 8 columns]

# %%
poverty_headcount.columns
# Out:
# Index(['Year', 'value', 'indicator', 'Country Code', 'Country Name', 'Region',
#        'Income Group', 'Lending Type'],
#       dtype='object')

# %%
poverty_headcount_2000 = poverty_headcount.query("Year == 2000")

poverty_headcount_2000 .sample(5)
# Out:
#      Year      value  ...         Income Group Lending Type
# 35   2000   9.361176  ...          High income         IBRD
# 96   2000  33.851749  ...  Upper middle income         IBRD
# 58   2000  15.713312  ...  Upper middle income         IBRD
# 157  2000   3.583435  ...          High income         IBRD
# 72   2000  46.441582  ...  Upper middle income         IBRD
#
# [5 rows x 8 columns]

# %%
poverty_headcount_2000 = poverty_headcount_2000.query("indicator in ['1.0.HCount.2.5usd']")

poverty_headcount_2000
# Out:
#      Year      value  ...         Income Group Lending Type
# 11   2000  43.250916  ...  Lower middle income         IBRD
# 35   2000   9.361176  ...          High income         IBRD
# 58   2000  15.713312  ...  Upper middle income         IBRD
# 72   2000  46.441582  ...  Upper middle income         IBRD
# 96   2000  33.851749  ...  Upper middle income         IBRD
# 113  2000  19.544781  ...  Upper middle income         IBRD
# 157  2000   3.583435  ...          High income         IBRD
#
# [7 rows x 8 columns]

# %%
df_pivot = poverty_headcount_2000.pivot_table(index=['Country Code','Country Name','Region','Income Group','Lending Type'], columns= 'indicator').reset_index()
df_pivot.head()
# Out:
#           Country Code        Country Name  ...              Year             value
# indicator                                   ... 1.0.HCount.2.5usd 1.0.HCount.2.5usd
# 0                  BOL             Bolivia  ...              2000         43.250916
# 1                  CHL               Chile  ...              2000          9.361176
# 2                  DOM  Dominican Republic  ...              2000         15.713312
# 3                  ECU             Ecuador  ...              2000         46.441582
# 4                  GTM           Guatemala  ...              2000         33.851749
#
# [5 rows x 7 columns]

# %%
fig = px.scatter(
    poverty_headcount_2000.dropna(),
    x="Year",
    y="value",
    title="Poverty Headcount",
    hover_name="Country Name",
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0231daa7-7c32-47ff-933c-1d24968663b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0231daa7-7c32-47ff-933c-1d24968663b8")) {
#                     Plotly.newPlot(
#                         '0231daa7-7c32-47ff-933c-1d24968663b8',
# ...

# %%
Labour_Income_Poverty_Index_2004 = poverty_headcount.query("Year == 2004")
Labour_Income_Poverty_Index_2004
# Out:
#      Year      value  ...         Income Group Lending Type
# 0    2004  16.963144  ...  Upper middle income         IBRD
# 26   2004  23.951452  ...  Upper middle income         IBRD
# 44   2004  28.392906  ...  Upper middle income         IBRD
# 62   2004  27.766209  ...  Upper middle income         IBRD
# 74   2004  28.805305  ...  Upper middle income         IBRD
# 85   2004  21.832012  ...  Lower middle income         IBRD
# 102  2004  46.768871  ...  Lower middle income          IDA
# 115  2004  14.729934  ...  Upper middle income         IBRD
# 135  2004  20.824310  ...  Upper middle income         IBRD
# 146  2004  25.767765  ...  Upper middle income         IBRD
# 161  2004   9.780787  ...          High income         IBRD
# 706  2004   1.420575  ...  Upper middle income         IBRD
#
# [12 rows x 8 columns]

# %%
Labour_Income_Poverty_Index_2004 = poverty_headcount_2000.query("indicator in ['1.0.HCount.2.5usd','8.0.LIPI']")

Labour_Income_Poverty_Index_2004
# Out:
#      Year      value  ...         Income Group Lending Type
# 11   2000  43.250916  ...  Lower middle income         IBRD
# 35   2000   9.361176  ...          High income         IBRD
# 58   2000  15.713312  ...  Upper middle income         IBRD
# 72   2000  46.441582  ...  Upper middle income         IBRD
# 96   2000  33.851749  ...  Upper middle income         IBRD
# 113  2000  19.544781  ...  Upper middle income         IBRD
# 157  2000   3.583435  ...          High income         IBRD
#
# [7 rows x 8 columns]

# %%
df_pivot = Labour_Income_Poverty_Index_2004.pivot_table(index=['Country Code','Country Name','Region','Income Group','Lending Type','value'], columns= 'indicator').reset_index()
df_pivot.head(10)
# Out:
#           Country Code        Country Name  ...      value              Year
# indicator                                   ...            1.0.HCount.2.5usd
# 0                  BOL             Bolivia  ...  43.250916              2000
# 1                  CHL               Chile  ...   9.361176              2000
# 2                  DOM  Dominican Republic  ...  15.713312              2000
# 3                  ECU             Ecuador  ...  46.441582              2000
# 4                  GTM           Guatemala  ...  33.851749              2000
# 5                  MEX              Mexico  ...  19.544781              2000
# 6                  URY             Uruguay  ...   3.583435              2000
#
# [7 rows x 7 columns]

# %%
fig = px.bar(
    df,
    x="Year",
    y="value",
    title="Labour Income Poverty Index",
    color="Country Name",
     # this is used to show the name when mouse is moved on the dot. 
    #text="Country Name", # text is used to display a name all time. 
    
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f006a8a8-1144-4c04-8850-5d1e45d848a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f006a8a8-1144-4c04-8850-5d1e45d848a9")) {
#                     Plotly.newPlot(
#                         'f006a8a8-1144-4c04-8850-5d1e45d848a9',
# ...

# %%
multidimensional_children = pd.read_csv("/content/wdi_data (7).csv")
multidimensional_children.drop(columns=["Unnamed: 0"], inplace=True)
multidimensional_children.head()
# Out:
#    Year      value  ...         Income Group Lending Type
# 0  2004  16.963144  ...  Upper middle income         IBRD
# 1  2005  13.317249  ...  Upper middle income         IBRD
# 2  2006  10.317365  ...  Upper middle income         IBRD
# 3  2007   8.750589  ...  Upper middle income         IBRD
# 4  2008   8.210397  ...  Upper middle income         IBRD
#
# [5 rows x 8 columns]

# %%
multidimensional_children_data = multidimensional_children.query("indicator in ['1.0.HCount.2.5usd','8.0.LIPI']")

multidimensional_children_data
# Out:
#      Year      value  ...         Income Group Lending Type
# 0    2004  16.963144  ...  Upper middle income         IBRD
# 1    2005  13.317249  ...  Upper middle income         IBRD
# 2    2006  10.317365  ...  Upper middle income         IBRD
# 3    2007   8.750589  ...  Upper middle income         IBRD
# 4    2008   8.210397  ...  Upper middle income         IBRD
# ..    ...        ...  ...                  ...          ...
# 800  2010   0.998376  ...          High income         IBRD
# 801  2011   0.832277  ...          High income         IBRD
# 802  2012   0.786716  ...          High income         IBRD
# 803  2013   0.778537  ...          High income         IBRD
# 804  2014   0.760867  ...          High income         IBRD
#
# [271 rows x 8 columns]

# %%
df_pivot =multidimensional_children.pivot_table(index=['Country Code','Country Name','Region','Income Group','Lending Type','value'], columns= 'indicator').reset_index()
df_pivot.head(10)
# Out:
#           Country Code Country Name  ...           Year
# indicator                            ... SI.POV.MDIM.MA SI.POV.MDIM.XQ
# 0                  AFG  Afghanistan  ...            NaN         2020.0
# 1                  AFG  Afghanistan  ...            NaN         2016.0
# 2                  AFG  Afghanistan  ...            NaN            NaN
# 3                  AFG  Afghanistan  ...            NaN            NaN
# 4                  AGO       Angola  ...            NaN         2015.0
# 5                  AGO       Angola  ...            NaN            NaN
# 6                  ARG    Argentina  ...            NaN            NaN
# 7                  ARG    Argentina  ...            NaN            NaN
# 8                  ARG    Argentina  ...            NaN            NaN
# 9                  ARG    Argentina  ...            NaN            NaN
#
# [10 rows x 12 columns]

# %%
fig = px.bar(
    multidimensional_children_data,
    title = "Multidimensional Poverty Headcount Ratio, Children(% of Population 0-17)",
    labels = {"value":"Poverty Headcount","Year":"YEAR"},
    orientation="v",
    x= 'Year',
    y = 'value'
    
)
fig.update_xaxes(tickangle=45)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="056286a6-1207-4383-8631-b472e202b13f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("056286a6-1207-4383-8631-b472e202b13f")) {
#                     Plotly.newPlot(
#                         '056286a6-1207-4383-8631-b472e202b13f',
# ...

# %%
multidimensional_male= pd.read_csv("/content/wdi_data (7).csv")
multidimensional_male.drop(columns=["Unnamed: 0"], inplace=True)
multidimensional_male.head()
# Out:
#    Year      value  ...         Income Group Lending Type
# 0  2004  16.963144  ...  Upper middle income         IBRD
# 1  2005  13.317249  ...  Upper middle income         IBRD
# 2  2006  10.317365  ...  Upper middle income         IBRD
# 3  2007   8.750589  ...  Upper middle income         IBRD
# 4  2008   8.210397  ...  Upper middle income         IBRD
#
# [5 rows x 8 columns]

# %%
multidimensional_male.columns
# Out:
# Index(['Year', 'value', 'indicator', 'Country Code', 'Country Name', 'Region',
#        'Income Group', 'Lending Type'],
#       dtype='object')

# %%
multidimensional_men_data = multidimensional_children.query("indicator in ['SI.POV.MDIM.FE']")

multidimensional_men_data
# Out:
#      Year  value  ...         Income Group    Lending Type
# 530  2018   25.0  ...  Upper middle income            IBRD
# 531  2015   19.1  ...          High income  Not classified
# 532  2016   18.9  ...          High income  Not classified
# 533  2017   19.3  ...          High income  Not classified
# 534  2018   18.7  ...          High income  Not classified
# ..    ...    ...  ...                  ...             ...
# 701  2015   42.4  ...  Upper middle income            IBRD
# 702  2016   46.1  ...  Upper middle income            IBRD
# 703  2017   42.6  ...  Upper middle income            IBRD
# 704  2018   41.0  ...  Upper middle income            IBRD
# 705  2019   41.0  ...  Upper middle income            IBRD
#
# [176 rows x 8 columns]

# %%
multidimensional_men_data.columns
# Out:
# Index(['Year', 'value', 'indicator', 'Country Code', 'Country Name', 'Region',
#        'Income Group', 'Lending Type'],
#       dtype='object')

# %%
df_pivot =multidimensional_men_data.pivot_table(index=['Country Code','Country Name','Region','Income Group','Lending Type','value'], columns= 'indicator').reset_index()
df_pivot.head(10)
# Out:
#           Country Code Country Name  ... value           Year
# indicator                            ...       SI.POV.MDIM.FE
# 0                  ARM      Armenia  ...  25.0         2018.0
# 1                  AUT      Austria  ...  18.3         2019.0
# 2                  AUT      Austria  ...  18.7         2018.0
# 3                  AUT      Austria  ...  18.9         2016.0
# 4                  AUT      Austria  ...  19.1         2015.0
# 5                  AUT      Austria  ...  19.3         2017.0
# 6                  BEL      Belgium  ...  20.0         2019.0
# 7                  BEL      Belgium  ...  20.9         2018.0
# 8                  BEL      Belgium  ...  21.8         2017.0
# 9                  BEL      Belgium  ...  22.2         2015.0
#
# [10 rows x 7 columns]

# %%
fig = go.Figure()

trace_0 = go.Bar(      
    x=df_pivot["Year"],    
    y=df_pivot["value"]
)

fig.add_trace(trace_0)

fig.update_layout(
    title="Multidimensional Poverty Headcount Ratio, Male(% of Male Population",
    xaxis_title="YEAR",
    yaxis_title="Male Poverty Headcount"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f090b124-eaeb-4db8-bd4a-fc3076d99607" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f090b124-eaeb-4db8-bd4a-fc3076d99607")) {
#                     Plotly.newPlot(
#                         'f090b124-eaeb-4db8-bd4a-fc3076d99607',
# ...

# %%
fig = px.pie(df_pivot, values='SP.POP.TOTL', names='Country Name', title='Total Population',hover_name='Country Name')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-06a5a06aeb43> in <module>()
# ----> 1 fig = px.pie(df_pivot, values='SP.POP.TOTL', names='Country Name', title='Total Population',hover_name='Country Name')
#       2 fig.update_traces(textposition='inside', textinfo='percent+label')
#       3 fig.show()
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_chart_types.py in pie(data_frame, names, values, color, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, opacity, hole)
#    1232         constructor=go.Pie,
#    1233         trace_patch=dict(showlegend=(names is not None), hole=hole),
# -> 1234         layout_patch=layout_patch,
#    1235     )
#    1236
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
# ...

# %%
fig = px.line(
    df_pivot.dropna(),
    x="Year", 
    y="SI.POV.MDIM.FE",
    color='Country Name',
    
)
fig.update_xaxes(type='category')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-67-9bb33e26def8> in <module>()
#       3     x="Year",
#       4     y="SI.POV.MDIM.FE",
# ----> 5     color='Country Name',
#       6
#       7 )
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     212     a polyline mark in 2D space.
#     213     """
# --> 214     return make_figure(args=locals(), constructor=go.Scatter)
#     215
#     216
#
# ...
